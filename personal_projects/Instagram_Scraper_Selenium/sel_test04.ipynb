# %%
# Selenium imports
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains

# other imports
import random 
import time

# %%
#class Login_Insta():
    
def login_function(user_name="riya26feb", pass_word="w4h7@6t9e"):

        wd_path = r'C:/Users/2me41/Downloads/chromedriver_win32(1)/chromedriver.exe'
        driv = webdriver.Chrome(wd_path)
        # tell drive which url to open
        url = 'https://www.instagram.com/'
        driv.get(url)

        # trying to login into page (using By css selector)
        username = WebDriverWait(driv, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='username']")))
        password = WebDriverWait(driv, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='password']")))
        username.clear()
        password.clear()
        username.send_keys(user_name) # your user name
        password.send_keys(pass_word) # your password

        # Clicking the login button
        WebDriverWait(driv, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button[type='submit']"))).click()
        # save your login info? Not Now
        WebDriverWait(driv, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[contains(text(), 'Not Now')]"))).click()
        # turn on notification? Not Now
        WebDriverWait(driv, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[contains(text(), 'Not Now')]"))).click()
        
        time.sleep(2)
        return driv

# %%
#class Search_class(Login_Insta):

def hash_tags(driv, to_search_for='#abstractart'):
        """searching the hash_tag and opening up that page"""

        #driv = self.driv
        time.sleep(4.00 + (float('{0:.3f}'.format(random.random()*(1)))))
        # for searching anything 
        searchbox = WebDriverWait(driv, 10).until(EC.element_to_be_clickable((By.XPATH, "//input[@placeholder='Search']")))
        searchbox.clear()
        #to_search_for = '#abstractart'
        searchbox.send_keys(to_search_for)  #.send_keys(Keys.ENTER)
        # to click enter
        time.sleep(2.00 + (float('{0:.3f}'.format(random.random()*(1)))))
        searchbox.send_keys(Keys.ENTER)

        try:
            searchbox.send_keys(Keys.ENTER)
        except:
            pass

        time.sleep(2.00 + (float('{0:.3f}'.format(random.random()*(1)))))
        return driv

# %%
my_driv = login_function()
# Out:
# C:\Users\2me41\AppData\Local\Temp\ipykernel_7916\1487942528.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driv = webdriver.Chrome(wd_path)

# %%
my_driv2 = hash_tags(my_driv)

# %%
from seleniumwire import webdriver  # Import from seleniumwire

# %%
wd_path = r'C:/Users/2me41/Downloads/chromedriver_win32(1)/chromedriver.exe'
driver = webdriver.Chrome(wd_path)
driver.get('https://google.com')

for request in driver.requests:
    if request.response:
        print(
            request.url('https://i.instagram.com/api/v1/tags/abstractart/sections/'),
            request.response.status_code,
            request.response.headers['Content-Type']
        )
# Out:
# https://accounts.google.com/ListAccounts?gpsia=1&source=ChromiumBrowser&json=standard 200 application/json; charset=utf-8
# https://google.com/ 301 text/html; charset=UTF-8
# https://www.google.com/ 200 text/html; charset=UTF-8
# https://www.google.com/xjs/_/js/k=xjs.s.en_GB.0RwjdeQGgkw.O/am=AIACgQDwAgAIAEBmAAEAAAAAAAAAAIYAIPGUEwAADBACAjkJAAAAACRMiAAAYAAgBDAQhAAAAAA-Mm8AAv4MAAw04QIAAAAAAAAACOASBAM3SBQEAAIAAAAAACCspq44AAVB/d=1/ed=1/dg=2/br=1/rs=ACT90oGwN7ozERkbV3PVMtjjln0gCJJKeQ/m=cdos,dpf,hsm,jsa,d,csi 200 text/javascript; charset=UTF-8
# https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png 200 image/png
# https://www.google.com/gen_204?s=webhp&t=cap&atyp=csi&ei=KWsMY5qDAaCl1e8P8uyx2AI&rt=wsrt.3630,aft.143&wh=662&bl=IuYP 204 text/html; charset=UTF-8
# https://www.google.com/images/searchbox/desktop_searchbox_sprites318_hr.webp 200 image/webp
# ...

# %%
driver.get('https://www.instagram.com/')

# %%
from seleniumwire.utils import decode

# %%
from seleniumwire.utils import decode as sw_decode

# %%
body_str = """
{"sections":[{"layout_type":"media_grid","layout_content":{"medias":[{"media":{"taken_at":1661767775,"pk":"2915441869900510220","id":"2915441869900510220_2277711966","device_timestamp":77715703755683,"media_type":1,"code":"Ch1uu8auHQM","client_cache_key":"MjkxNTQ0MTg2OTkwMDUxMDIyMA==.2","filter_type":0,"accessibility_caption":"Photo by Pava Wülfert on August 29, 2022. May be art.","is_unified_video":false,"should_request_ads":false,"caption_is_edited":false,"like_and_view_counts_disabled":false,"commerciality_status":"not_commercial","is_paid_partnership":false,"is_visual_reply_commenter_notice_enabled":true,"original_media_has_visual_reply_media":false,"has_delayed_metadata":false,"comment_likes_enabled":false,"comment_threading_enabled":true,"has_more_comments":false,"max_num_visible_preview_comments":2,"preview_comments":[],"comments":[],"can_view_more_preview_comments":false,"comment_count":0,"hide_view_all_comment_entrypoint":false,"image_versions2":{"candidates":[{"width":1440,"height":1540,"url":"https://instagram.fbho4-4.fna.fbcdn.net/v/t51.2885-15/302097478_483807083564701_3159560141068999851_n.webp?stp=dst-jpg_e35\u0026_nc_ht=instagram.fbho4-4.fna.fbcdn.net\u0026_nc_cat=101\u0026_nc_ohc=IiDZj2k7TzEAX9WjDvW\u0026edm=AMKDjl4BAAAA\u0026ccb=7-5\u0026ig_cache_key=MjkxNTQ0MTg2OTkwMDUxMDIyMA%3D%3D.2-ccb7-5\u0026oh=00_AT8iQHO3rxolIhS4mP7Ytr_F8Iy99_SxT_Tof6oyoiClkg\u0026oe=6314792F\u0026_nc_sid=1fe099"},{"width":1080,"height":1155,"url":"https://instagram.fbho4-4.fna.fbcdn.net/v/t51.2885-15/302097478_483807083564701_3159560141068999851_n.webp?stp=dst-jpg_e35_p1080x1080\u0026_nc_ht=instagram.fbho4-"""

# %%
body_str.replace('"', '').replace('_', '').replace(':', ' ')
# Out:
# '\n{sections [{layouttype mediagrid,layoutcontent {medias [{media {takenat 1661767775,pk 2915441869900510220,id 29154418699005102202277711966,devicetimestamp 77715703755683,mediatype 1,code Ch1uu8auHQM,clientcachekey MjkxNTQ0MTg2OTkwMDUxMDIyMA==.2,filtertype 0,accessibilitycaption Photo by Pava Wülfert on August 29, 2022. May be art.,isunifiedvideo false,shouldrequestads false,captionisedited false,likeandviewcountsdisabled false,commercialitystatus notcommercial,ispaidpartnership false,isvisualreplycommenternoticeenabled true,originalmediahasvisualreplymedia false,hasdelayedmetadata false,commentlikesenabled false,commentthreadingenabled true,hasmorecomments false,maxnumvisiblepreviewcomments 2,previewcomments [],comments [],canviewmorepreviewcomments false,commentcount 0,hideviewallcommententrypoint false,imageversions2 {candidates [{width 1440,height 1540,url https //instagram.fbho4-4.fna.fbcdn.net/v/t51.2885-15/3020974784838070835647013159560141068999851n.webp?stp=dst-jpge35&ncht
# ...

# %%
import re

# %%
commentcount = re.findall('commentcount.[0-9]+', body_str)
#commentcount = int(commentcount[0][12:])
commentcount
# Out:
# []

# %%
#from crypt import methods


for request in driver.requests:
    if request.response and "sections" in request.url:
        body = sw_decode(request.response.body, request.response.headers.get('Content-Encoding', 'identity'))
        body = body.decode("utf8")
        print(type(body))
        print(len(body))
        print(body)
        print()
        print()
        #print(
            #request.url,
            #request.path,
            #request.params,
            #request.method.swapcase,
            #request.response.status_code,
            #request.response.body
            #decode(request.response.body, request.response.headers.get('Content-Encoding', 'identity')))
# Out:
# <class 'str'>
# 724061
# ...

# %%
sample_link = "https://www.instagram.com/p/Ch1aLjBOQOw/"

# %%
my_driv2.get(sample_link)

# %%
for request in my_driv2.requests:
    if request.response:
        print(
            request.url,
            request.response.status_code,
            request.response.headers['Content-Type']
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\VS_Code_folder\Selenium_test\sel_test04.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> for request in my_driv2.requests:
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     if request.response:
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>         print(
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>             request.url,
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>             request.response.status_code,
# ...

# %%
# Go to the Google home page
my_driv2.get('https://www.google.com')

# Access requests via the `requests` attribute
for request in my_driv2.requests:
    if request.response:
        print(
            request.url,
            request.response.status_code,
            request.response.headers['Content-Type']
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\VS_Code_folder\Selenium_test\sel_test04.ipynb Cell 12 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> my_driv2.get('https://www.google.com')
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> # Access requests via the `requests` attribute
# ----> <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> for request in my_driv2.requests:
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>     if request.response:
#       <a href='vscode-notebook-cell:/c%3A/VS_Code_folder/Selenium_test/sel_test04.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>         print(
# ...
