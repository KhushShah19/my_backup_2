# %%
import os, sys
sys.path.append(os.getcwd().split("final_work")[0][:-1])
import bot
#os.environ['BASE_PATH'] = "C:/VS_Code_folder/Intern_projects/pharmeasy_reviews_extraction"

# %%
pharm = bot.SeleniumBot()

# %%
given_link = "https://pharmeasy.in/health-care/products/himalaya-liv-52-ds-tablets---60-s-12836"
pharm.get_data(my_link=given_link, store_data=True)
# Out:
# 12836 ==> https://pharmeasy.in/health-care/products/himalaya-liv-52-ds-tablets---60-s-12836
# 5 page are completed for 12836
# 10 page are completed for 12836
# 15 page are completed for 12836
# 20 page are completed for 12836
# {'data': [{'customerName': 'Tara Chand Pandey',
#    'score': 5,
#    'review': '"Effective medcin for liver problem"',
#    'posted': '32 months ago'},
#   {'customerName': 'Sandhya Sangai',
#    'score': 5,
#    'review': 'Satisfied',
#    'posted': '32 months ago'},
#   {'customerName': 'Sourav',
#    'score': 5,
#    'review': '"Product is very effective"',
#    'posted': '31 months ago'},
#   {'customerName': 'Khairul Islam',
#    'score': 4,
#    'review': '"Very good"',
#    'posted': '31 months ago'},
#   {'customerName': 'Sameer Naidu',
#    'score': 5,
#    'review': '"."',
#    'posted': '31 months ago'},
#   {'customerName': 'Manzoor Ahmad Masoodi',
#    'score': 5,
#    'review': '"Good"',
#    'posted': '30 months ago'},
# ...

# %%
given_link = "https://pharmeasy.in/health-care/products/herbal-hills-liv-first-60-tablets---pack-of-2-3807358"
pharm.get_data(my_link=given_link, store_data=True)
# Out:
# 3807358 ==> https://pharmeasy.in/health-care/products/herbal-hills-liv-first-60-tablets---pack-of-2-3807358
# {'status': 0, 'error': 'No data fetched from ES.'}

# %%
given_link = "https://pharmeasy.in/health-care/products/dettol-antiseptic-liquid-bottle-of-250-ml-236383"
pharm.get_data(my_link=given_link, store_data=True)
# Out:
# 236383 ==> https://pharmeasy.in/health-care/products/dettol-antiseptic-liquid-bottle-of-250-ml-236383
# 5 page are completed for 236383
# {'data': [{'customerName': 'PharmEasy User',
#    'score': 4,
#    'review': 'Good',
#    'posted': '35 months ago'},
#   {'customerName': 'Cx1059',
#    'score': 4,
#    'review': 'Good and apt delivery',
#    'posted': '34 months ago'},
#   {'customerName': 'Komal Rawat',
#    'score': 3,
#    'review': 'I like it',
#    'posted': '34 months ago'},
#   {'customerName': 'Soumyananda Samanta',
#    'score': 5,
#    'review': 'Thanks',
#    'posted': '34 months ago'},
#   {'customerName': 'Keshav',
#    'score': 5,
#    'review': 'Appropriate and latest. On time delivery.',
#    'posted': '34 months ago'},
#   {'customerName': 'Jason Fernandes',
#    'score': 5,
#    'review': 'Great service by Pharmeasy',
#    'posted': '35 months ago'},
#   {'customerName': 'Inderjit Badyal',
#    'score': 5,
#    'review': 'All is well',
# ...

# %%
given_link = "https://pharmeasy.in/health-care/products/dettol-instant-original-hand-sanitizer-bottle-of-200-ml-171058"
pharm.get_data(my_link=given_link, store_data=True)
# Out:
# 171058 ==> https://pharmeasy.in/health-care/products/dettol-instant-original-hand-sanitizer-bottle-of-200-ml-171058
# {'data': [{'customerName': 'Abid Yatoo',
#    'score': 1,
#    'review': '"Not upto expectations"',
#    'posted': '26 months ago'},
#   {'customerName': 'Vrushabh',
#    'score': 4,
#    'review': '"Hope it\'s original"',
#    'posted': '23 months ago'},
#   {'customerName': 'Karthivsk@yahoo.co.in',
#    'score': 1,
#    'review': '"It not look original product    and itc nimwash delivered without company seal..I think it\'s fake.....over all worst experience...."',
#    'posted': '23 months ago'},
#   {'customerName': 'Dulal Dutta',
#    'score': 5,
#    'review': '"Nice prodect 👍"',
#    'posted': '23 months ago'},
#   {'customerName': 'Siddhartha Banerjee',
#    'score': 5,
#    'review': '"Good"',
#    'posted': '22 months ago'},
#   {'customerName': 'Sanjay Malik',
#    'score': 5,
#    'review': '"I like dettol sanitizer product is very nice"',
# ...

# %%
given_link = "https://pharmeasy.in/health-care/products/surgical-face-masks---3ply-1-3039136"
pharm.get_data(my_link=given_link, store_data=True)
# Out:
# 3039136 ==> https://pharmeasy.in/health-care/products/surgical-face-masks---3ply-1-3039136
# {'data': [{'customerName': 'Tanmay Parmar',
#    'score': 4,
#    'review': '"Good product."',
#    'posted': '25 months ago'},
#   {'customerName': 'Dilip sharma',
#    'score': 5,
#    'review': '"Ok"',
#    'posted': '24 months ago'},
#   {'customerName': 'Abinash',
#    'score': 1,
#    'review': '"Horrible quality, unusable- the thread comes off"',
#    'posted': '2 months ago'},
#   {'customerName': 'Mona Chaterjee',
#    'score': 3,
#    'review': '"The strings were very weak"',
#    'posted': '22 months ago'},
#   {'customerName': 'Anjali Jain',
#    'score': 5,
#    'review': '"Good"',
#    'posted': '24 months ago'},
#   {'customerName': 'Nitish',
#    'score': 1,
#    'review': '"It was not upto the standards of a surgical mask."',
#    'posted': '5 months ago'},
#   {'customerName': 'Revathi',
#    'score': 5,
#    'review': '"Liked this mask"',
#    'posted': '2 months ago'},
# ...
